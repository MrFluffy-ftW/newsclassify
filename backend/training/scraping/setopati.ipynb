# %%
import requests
from bs4 import BeautifulSoup as BS
import re

# %%
#url
url = "https://www.setopati.com/"
response = requests.get(url)
soup = BS(response.content, "html.parser")

# %%
CLEANR = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
def cleanhtml(raw_html):
  cleantext = re.sub(CLEANR, '', raw_html)
  return cleantext
def clean_text(text):
  clean_str = ""
  text_str = str(text)
  text_str = cleanhtml(text_str)
  text_str = text_str.replace("\xa0","")
  text_str = text_str.replace("\u202f","")
  text_str = text_str.replace("[","")
  text_str = text_str.replace("\'s","'s")
  clean_str += " "
  clean_str += text_str  
  return clean_str

# %%
'''Extracting links'''

actual_links = []
main_container = soup.find("div",id='content')
link = main_container.find_all("a")
# print(link)
temp_web_links = [web_link['href'] for web_link in link] 

#removing faltu links
for links in temp_web_links:
    if links.find("https://www.setopati.com") == 0:
        actual_links.append(links)

#removing duplicate links
actual_links = list(dict.fromkeys(actual_links))
print(actual_links)
# Out:
# ['https://www.setopati.com/politics/296325', 'https://www.setopati.com/politics/296323', 'https://www.setopati.com/politics/296322', 'https://www.setopati.com/social/296318', 'https://www.setopati.com/art/art-activity/296302', 'https://www.setopati.com/politics/296282', 'https://www.setopati.com/kinmel/banking/296326', 'https://www.setopati.com/kinmel/others/296324', 'https://www.setopati.com/politics/296320', 'https://www.setopati.com/politics/296319', 'https://www.setopati.com/sports/cricket/296317', 'https://www.setopati.com/politics/296314', 'https://www.setopati.com/social/296313', 'https://www.setopati.com/sports/cricket/296312', 'https://www.setopati.com/kinmel/tourism/296311', 'https://www.setopati.com/social/296309', 'https://www.setopati.com/sports/football/296307', 'https://www.setopati.com/politics/296308', 'https://www.setopati.com/politics/296304', 'https://www.setopati.com/politics/296301', 'https://www.setopati.com/politics/296300', 'https://www.setopati.com/politics/296299', 'https://www.setopati.com/politics/296316', 'https://www.setopati.com/politics/296306', 'https://www.setopati.com/politics/296297', 'https://www.setopati.com/social/296295', 'https://www.setopati.com/politics/296291', 'https://www.setopati.com/social/296290', 'https://www.setopati.com/social/296286', 'https://www.setopati.com/politics/296281', 'https://www.setopati.com/social/296278', 'https://www.setopati.com/social/296267', 'https://www.setopati.com/politics/296260', 'https://www.setopati.com/politics/296258', 'https://www.setopati.com/multimedia', 'https://www.setopati.com/social/295878', 'https://www.setopati.com/social/295796', 'https://www.setopati.com/kinmel/banking/295755', 'https://www.setopati.com/politics/295475', 'https://www.setopati.com/politics/295447', 'https://www.setopati.com/politics/295435', 'https://www.setopati.com/photo-gallery', 'https://www.setopati.com/photo-detail/5374', 'https://www.setopati.com/photo-detail/5375', 'https://www.setopati.com/photo-detail/5376', 'https://www.setopati.com/photo-detail/5377', 'https://www.setopati.com/photo-detail/5378', 'https://www.setopati.com/kinmel', 'https://www.setopati.com/kinmel/banking/296310', 'https://www.setopati.com/kinmel/economy/296292', 'https://www.setopati.com/kinmel/tourism/295906', 'https://www.setopati.com/kinmel/banking/296275', 'https://www.setopati.com/kinmel/business/296266', 'https://www.setopati.com/kinmel/tourism/296265', 'https://www.setopati.com/kinmel/others/296264', 'https://www.setopati.com/kinmel/tourism/296256', 'https://www.setopati.com/kinmel/tourism/296247', 'https://www.setopati.com/kinmel/banking/296244', 'https://www.setopati.com/kinmel/business/296241', 'https://www.setopati.com/kinmel/jewellery/296237', 'https://www.setopati.com/kinmel/tourism/296219', 'https://www.setopati.com/kinmel/business/296262', 'https://www.setopati.com/kinmel/automobiles/296180', 'https://www.setopati.com/kinmel/banking/296159', 'https://www.setopati.com/kinmel/others/296200', 'https://www.setopati.com/kinmel/others/296157', 'https://www.setopati.com/kinmel/business/296155', 'https://www.setopati.com/kinmel/economy/296197', 'https://www.setopati.com/kinmel/others/296115', 'https://www.setopati.com/kinmel/banking/296113', 'https://www.setopati.com/%E0%A4%85%E0%A4%B0%E0%A5%8D%E0%A4%A5-%E0%A4%B8%E0%A4%AE%E0%A4%BE%E0%A4%9A%E0%A4%BE%E0%A4%B0', 'https://www.setopati.com/nepali-brand', 'https://www.setopati.com/nepali-brand/296126', 'https://www.setopati.com/nepali-brand/295564', 'https://www.setopati.com/nepali-brand/295524', 'https://www.setopati.com/nepali-brand/295452', 'https://www.setopati.com/nepali-brand/294259', 'https://www.setopati.com/nepali-brand/294026', 'https://www.setopati.com/global', 'https://www.setopati.com/global/australia/296217', 'https://www.setopati.com/global/australia/296143', 'https://www.setopati.com/global/america/296024', 'https://www.setopati.com/global/australia/296059', 'https://www.setopati.com/global/australia/295455', 'https://www.se ...

# %%
paragraph = []
date = []
title = []
news_link = []
#extracting news articles
for link in actual_links:
    try:
        url = link
        response = requests.get(url)
        soup = BS(response.content, "html.parser")
        heading = soup.find("h1",class_='news-big-title').getText()
        print(heading,"\n")
        news_body = soup.find("div",class_='editor-box')
        temp = news_body.find_all("p")
        temp_clean = clean_text(temp)
        paragraph.append(temp_clean)
        title.append(heading)
        time = soup.find("span",class_='main-title').getText()
        date.append(time)
        news_link.append(link)
    except:
        continue
# Out:
# प्रधानमन्त्री प्रचण्डविरूद्धको रिट न्यायाधीश ईश्वरप्रसाद खतिवडाको इजलासमा
#
# तेस्रो कार्यकालका लागि राष्ट्रपति चुनिए सी चिनफिङ
#
# सर्वोच्चले क्षेत्राधिकार मिचेको भन्दै माओवादी घटकहरूले संघर्ष गर्ने
#
# अटोरिक्साको कमाइले घर चलाउने हरिनाथ
#
# जसले पूरा गरिदिन्छन् गायकहरूका सपना!
#
# ६० वर्ष लामो आरोह-अवरोहपछि मुलुकको सर्वोच्च पदमा रामचन्द्र
#
# आजबाट सानिमा मिडिल तमोरको आइपिओ निष्कासन
#
# प्रतितोला आठ सय रुपैयाँ बढ्यो सुन, कतिमा हुँदैछ कारोबार?
#
# निवासमै पुगेर नवनिर्वाचित राष्ट्रपतिलाई सभामुखको बधाई
#
# उत्तरी जर्मनीको ह्याम्बर्गस्थित एक चर्चमा गोली चल्यो, कैयौँको मृत्यु
#
# युएईसँग टस हारेको पिएनजी पहिले ब्याटिङ गर्दै
#
# प्रधानमन्त्री दाहालविरुद्ध सर्वोच्चमा परेको रिटको सुनुवाइ आज
#
# मनाङमा हिमपात
#
# आईसीसी विश्व क्रिकेट लिग-२ः  यूएई र पीएनजी भिड्दै
#
# इन्जिनको सुरक्षा जाँच नसकुन्जेल प्राधिकरणले रोक्यो श्री एयरलाइन्सका उडान
#
# गण्डकी प्रदेशका पहाडी भू-भागमा मेघ गर्जनसहित हल्का वर्षाको सम्भावना
#
# म्यानचेस्टर युनाइटेडको सानदार जित
#
# कांग्रेस सांसद चन्द्र भण्डारीको स्वास्थ्यमा सुधार
#
# मेरो तर्फबाट साथ, सहयोग र समर्थन रहन्छ- उपाध्यक्ष नेम्वाङ
#
# राष्ट्रपतिमा निर्वाचित भएपछि रामचन्द्र पौडेललाई बालुवाटारमा स्वागत
#
# भगवानपुर गाउँपालिका अध्यक्षको घरमा मन्त्री, सिडिओ र प्रहरीकै अघि जातीय छुवाछुत
#
# विशेष अदालतले सुनायो भ्रष्टाचारी ठहर भएका पूर्वमन्त्री न्यौपानेलाई साढे ९ वर्ष कैद र जरिवाना
#
# बालुवाटारमा माओवादी धारका दलहरूको बैठक जारी
#
# राष्ट्रपति पौडेल आज पशुपति र बिपी संग्रहालय जाने
#
# रामचन्द्र पौडेल राष्ट्रपतिमा निर्वाचित भएपछि... (तस्बिरहरू)
#
# सैनामैनामा युवकको हत्या आरोपमा तीन जना पक्राउ
#
# नवनिर्वाचित राष्ट्रपति पौडेललाई सभापति देउवाको बधाई
#
# साढे दुई किलो चरेससहित एक महिला पक्राउ
#
# ललितपुर महानगरका शिक्षा अधिकृत एक लाख घुससहित पक्राउ
#
# राष्ट्रपति निर्वाचनमा को-को सांसद अनुपस्थित
#
# बिना प्रष्क्रिप्सन औषधी किनबेच गरेको आरोपमा १४ जना पक्राउ
#
# कञ्चनपुरमा जिपले मोटरसाइकललाई ठक्कर दिँदा एक जनाको मृत्यु
#
# नेमकिपाले राष्ट्रपति उम्मेदवारलाई भोट नहाल्ने
#
# राष्ट्रपति निर्वाचनमा १ बजेसम्म छ सय ९४ मतदान
#
# जो आवाजबाटै चिन्छन् ४ सय चरा
#
# सुगर दीर्घ रोग होइन, स्वस्थ जीवनशैली अपनाए औषधि छोड्न मिल्छ (भिडिओ)
#
# अर्थतन्त्रको समस्या र बैंकको भूमिकाबारे के भन्छन् अनिल केशरी शाह (भिडि‌ओ)
#
# माधव नेपाललाई हामीले पार्टी एकता गर्नुपर्दैन, तपाईं राष्ट्रपति बन्नुस् भनेका थियौं: बिष्णु रिमाल (भिडिओ)
#
# हो, दुई महिना प्रचण्डलाई साँच्चै गाह्रो भएको थियो: ओली (भिडिओ)
#
# ओलीले भने- प्रचण्डले मलाई धोका दिनु कुन ठूलो कुरा भो र! (भिडिओ)
#
# घट्यो डलर र  बढ्यो युरोको मूल्य, अन्य  मुद्राको किनबेच कतिमा भएको छ ?
#
# ८८ अर्ब ३१ करोड लगानीमा बुढीगण्डकी 'क' र 'ख' जलविद्युत आयोजना निर्माण हुने
#
# पर्यटनमन्त्री सुदन किरातीलाई १० प्रश्न
#
# एकै दिन ५० अंकले बढ्यो नेप्से, ब्याजदर घट्ने संकेतले बजारमा सुधार
#
# निजी क्षेत्रको प्रतिष्ठा बढाउने गरी काम गर्नेछुः वरिष्ठ उपाध्यक्ष ढकाल
#
# गौतमबुद्ध अन्तर्राष्ट्रिय विमानस्थलबाट जजिरा एयरवेजको पुनः उडान सुरू
#
# मध्य भोटेकोसीको बिजुली खेर गए ठेकेदारबाटै असुल्ने प्राधिकरणको चेतावनी
#
# भेडेटारमा ३० करोड लगानीमा 'स्काई वाक' बन्दै
#
# बुद्ध एयरमा यात्रा गर्ने ३५ सय महिलाले पाए पुस्तक उपहार
#
# नयाँ ऋणको ब्याजदर चैतबाट घट्ने, पुरानोको वैशाखबाट
#
# कोका-कोलाको सक्षम २.०, एक हजार महिलालाई डिजिटल सीपमार्फत सशक्त बनाउँदै
#
# प्रतितोला पाँच सय रुपैयाँ घट्यो सुन, कतिमा हुँदैछ कारोबार?
#
# विदेशी पर्यटकको रोजाइ बन्दै चितवनको पटिहानी
#
# हरेक महिनाको २५ गते इ-सेवाको 'इन्स्योरेन्स डे', प्रिमियम तिर्दा दुई सय रुपैयाँसम्म क्यासब्याक
#
# यातायात कार्यालय एकान्तकुनाको सेवा बिहान ८ बजेदेखि सुरू गर्ने तयारी
#
# स्मार्टच्वाइस र हिमालयन बैंकबीच स्मार्ट क्युआर भुक्तानी सेवा सञ्चालनको लागि सम्झौता
#
# महिला नेत्री ममता झा 'राष्ट्र नारी सम्मान २०७९' बाट सम्मानित
#
# कालीगण्डकी प्रसारण लाइन: तीन वर्षदेखिको अवरोध हटाइँदै
#
# नारी दिवसमा इसेवाको विशेष अफर, महिला उद्यमीसँग व्यवसाय सहकार्यमा तीन महिना छुट
#
# राजस्व परामर्श समितिले थाल्यो काम
#
# चेम्बरले गर्यो महिला उद्यमीलाई सम्मान
#
# रेमिटलीबाट पठाएको पैसा अब सिधै आइएमई पे वालेटमा
#
# सातै प्रदेशको रैथाने खाना पाक्ने भान्सा घर
#
# चिप्स बनाउँदा बनाउँदै फुरेको 'बा-को' लाई ब्रान्ड बनाउँदै रजिना
#
# विश्वविद्यालय प्रोजेक्टको आइडिया 'समसारा', ५४ हजार लगानीमा यसरी बन्यो व्यवसाय
#
# अदुवा-लसुन किन्न नपर्ने, सिलौटामा पिस्न नपर्ने!
#
# विजयले ४ हजारमा थालेको व्यवसाय, अहिले महिनामा १५ लाखको कारोबार
#
# दुई युवा इञ्जिनियरले १० लाखमा सुरू गरेको 'मस्तकला'
#
# शनिबार सिड्नीमा होली फेस्टिबल
#
# एडिलेडको एल्डर्स पार्कमा नेपाल फेस्टिवल आयोजना हुने
#
# अमेरिकामा ह्याप्पी होली (तस्बिरहरू)
#
# अष्ट्रेलियामा आगामी शनिबार नयाका क्रुज पार्टी
#
# दोहोरो नागरिकता विधेयक चाँडै पारित हुन्छ-संग्रौला
#
# दर्शकको रोजाइमा भ्वाइसको अस्ट्रेलिया यात्रा
#
# क्यानबेरामा पहिलो पटक नेपाल महोत्सव
#
# ३१ खेल कुरेपछि एकदिवसीय शतक प्रहार गरेका आशिफ
#
# आर्मीले मछिन्द्रलाई हरायो, एनआरटीमाथि जावलाखेलको जित
#
# नेपालले पिएनजीलाई हरायो, एकदिवसीय मान्यता जोगाउन अब एक खेल जिते पुग्ने
#
# पिएनजीविरूद्ध नेपालले बनायो हालसम्मकै उच्च रन
#
# महेश त्रिपाठी अभिनीत फिल्म 'हल्कारा' को टिजर सार्वजनिक (भिडिओ)
#
# रणवीर र श्रद्धाको फिल्म 'तू झुठी मैं मक्कार' ले पहिलो दिन कति कमायो?
#
# अभिनेत्री सुरक्षाले गरिन् बिहे (तस्बिरहरू)
#
# विदेशका ५० भन्दा बढी पर्दामा रिलिज भयो 'छक्का पन्जा ४'
#
# 'यौटा सपनाको अवसान' नाटक निर्देशन गर्दै अनुप बराल
#
# रहेनन् भारतीय अभिनेता तथा निर्देशक सतीश कौशिक
#
# धुलिखेल जिपलाइनमा होलीको रमाइलो (तस्बिरहरू)
#
# एक गाउँबाट अर्को गाउँ जान अनुमति लिनुपर्ने त्यो ठाउँ
#
# लमजुङको लिपे लेकमा क्याम्पिङ ट्रेक, जहाँबाट देखिन्छ काठमाडौंको शिवपुरी!
#
# आमा याङ्ग्री मुस्कुराउँदा...
#
# लमजुङको लिपे लेक ट्रेकिङ प्रवर्द्धन गर्दै टान गण्डकी र दोर्दी गाउँपालिका
#
# रजत महोत्सवमा झुम्यो स्याङ्जाको सिरूबारी
#
# एलोरामा अलप नम्बरको खुलदुली!
#
# मनोकांक्षा पूरा भएको त्यो दिन
#
# गुफा पसेको दिन!
#
# होलीसँग जोडिएका मिथिलाका चार कथा र गीतहरू
#
# काठमाडौं आजभोलि फागु हैन, होली खेल्छ
#
# राष्ट्रपति चुनावमा निर्वाचन आयोगले समातेको असंवैधानिक बाटो
#
# रूस–युक्रेन युद्धका एक वर्षः कसले के पाए, के गुमाए?
#
# मैत्रीपूर्ण प्रविधिमा महिलाको पहुँच!
#
# कहाँ गइन् होला ती लडाकु दिदी?
#
# हामी अघि कहिले बढ्ने?
#
# आर यू ओके?
#
# संघर्षभित्रका संघर्षहरू!
#
# निर्दयी म हुँ वा मेरो जागीर?
#
# जन्मँदैछु म पनि नारी दिवसकै दिन!
#
# प्रेमको पहिलो वर्ष भनौँ या अन्तिम!
#
# साथी र म
#
# आमाको लागि औषधी
#
# जीवन
#
# कम्मर कसौं न साथी!
#
# सुरेन्द्र पाण्डेको सचिवालयद्वारा खण्डन
#
# धन्न नेता भइनँ!
#
# माननीयज्यू, खै त रोजगारी?
#
# मानविकी संकायका डिनलाई खुलापत्र: शिक्षामा भाषाको अवरोध हटाइयोस्
#
# विनिमय दर
#
# शेयर बजार
#
# सुन चाँदि

# %%
print(len(news_link))
# Out:
# 114

# %%
import pandas as pd

df = pd.DataFrame()
for i in range(len(paragraph)):
    df = df.append({"title" : title[i],
                    "date" : date[i],
                    "news" : paragraph[i],
                    "news_link": news_link[i]},ignore_index = True)

df.to_csv("setopati.csv",index=False)
# Out:
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
# /tmp/ipykernel_11761/4192234467.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"title" : title[i],
